# %% [markdown]
# <a href="https://colab.research.google.com/github/afreenduthaluru-lab/DS--repo/blob/main/1A-program-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"

df = pd.read_csv(url)
df.to_csv("iris_output.csv", index=False)

print("The dataset has been successfully written to iris_output.csv")
# Out:
# The dataset has been successfully written to iris_output.csv
