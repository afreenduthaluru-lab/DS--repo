# %% [markdown]
# <a href="https://colab.research.google.com/github/afreenduthaluru-lab/DS--repo/blob/main/1A-program-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Online CSV dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"

# CSV file reading
df = pd.read_csv(url)

# Displaying the first five rows
print("First five rows of the dataset:")
print(df.head())

# Displaying dataset information
print("\nDataset Information:")
print(df.info())

# Displaying the shape of the dataset
print("\nNumber of rows and columns:")
print(df.shape)
